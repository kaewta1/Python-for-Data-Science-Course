# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series,DataFrame

import matplotlib.pyplot as plt

from matplotlib import rcParams
import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4
sb.set_style('whitegrid')

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]
plt.bar(x,y)
plt.xlabel('your x-axis label')
plt.ylabel('your x-axis label')
# Out:
# Text(0, 0.5, 'your x-axis label')

# %%
z = [1,2,3,4,5]

veh_type = ['bicycle','motiorbike','car','van','stroller']

plt.pie(z, labels = veh_type)
plt.show()

# %%
address = 'C:\\Users\\kaewt\\Desktop\\Exercise\\ch01\\01_05\\mtcars.csv'
cars = pd.read_csv(address)


cars.columns = ['car_names','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb',]


mpg = cars.mpg
fig = plt.figure()

ax =  fig.add_axes([.1, .1, 1, 1])
mpg.plot()

ax.set_xticks(range(32))
ax.set_xtickslabels(cars.car_names, rotation = 60,fontsize = 'medium')

ax.set_title('MIles per Fallon of Cars in Mtcars')

ax.set_xlabel('car names')
ax.set_ylabel('miles/gal')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-883bbbfc9de8> in <module>
#      13
#      14 ax.set_xticks(range(32))
# ---> 15 ax.set_xtickslabels(cars.car_names, rotation = 60,fontsize = 'medium')
#      16
#      17 ax.set_title('MIles per Fallon of Cars in Mtcars')
#
# AttributeError: 'Axes' object has no attribute 'set_xtickslabels'
